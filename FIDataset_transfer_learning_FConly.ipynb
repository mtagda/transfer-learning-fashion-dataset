# %%
import os
import torch
import torchvision
import numpy as np
import pandas as pd
from PIL import Image
from torch import optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data.sampler import SubsetRandomSampler
import time
from model_utils import *
from pytorch_helpers import *

# %matplotlib inline

# %% [markdown]
# # Explore and clean the data
# In this section, we want to explore the data and prepare for image classification.

# %%
# create a df from styles.csv neglecting lines with error
DATASET_PATH = '/mnt/fashion-dataset-1/fashion-dataset/'
styles = pd.read_csv(os.path.join(DATASET_PATH, "styles.csv"), error_bad_lines=False)
# Out:
# b'Skipping line 6044: expected 10 fields, saw 11\nSkipping line 6569: expected 10 fields, saw 11\nSkipping line 7399: expected 10 fields, saw 11\nSkipping line 7939: expected 10 fields, saw 11\nSkipping line 9026: expected 10 fields, saw 11\nSkipping line 10264: expected 10 fields, saw 11\nSkipping line 10427: expected 10 fields, saw 11\nSkipping line 10905: expected 10 fields, saw 11\nSkipping line 11373: expected 10 fields, saw 11\nSkipping line 11945: expected 10 fields, saw 11\nSkipping line 14112: expected 10 fields, saw 11\nSkipping line 14532: expected 10 fields, saw 11\nSkipping line 15076: expected 10 fields, saw 12\nSkipping line 29906: expected 10 fields, saw 11\nSkipping line 31625: expected 10 fields, saw 11\nSkipping line 33020: expected 10 fields, saw 11\nSkipping line 35748: expected 10 fields, saw 11\nSkipping line 35962: expected 10 fields, saw 11\nSkipping line 37770: expected 10 fields, saw 11\nSkipping line 38105: expected 10 fields, saw 11\nSkipping line 38275: expected 10 fields, saw 11\nSkipping line 38404: expected 10 fields, saw 12\n'

# %%
print(styles.head())
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
print(len(styles))
# Out:
# 44424

# %%
# Get the list of names of images that are available
imgs_available = os.listdir(DATASET_PATH + '/images')
print(len(imgs_available))
# Out:
# 44442

# %% [markdown]
# We want to check if each entry in styles.csv has a corresponding images listing. If not, we remove it from the dataframe.

# %%
# Check if each entry in styles.csv has a corresponding images listing. 
# If not, we remove it from the dataframe.
missing_img = []
for idx, line in styles.iterrows():
    if not os.path.exists(os.path.join(DATASET_PATH, 'images', str(line.id)+'.jpg')):
        print(os.path.join(DATASET_PATH, 'images', str(line.id)+'.jpg'))
        missing_img.append(idx)
        
styles.drop(styles.index[missing_img], inplace=True)
# Out:
# /mnt/fashion-dataset-1/fashion-dataset/images/39403.jpg
# /mnt/fashion-dataset-1/fashion-dataset/images/39410.jpg
# /mnt/fashion-dataset-1/fashion-dataset/images/39401.jpg
# /mnt/fashion-dataset-1/fashion-dataset/images/39425.jpg
# /mnt/fashion-dataset-1/fashion-dataset/images/12347.jpg

# %%
print(len(styles))
# Out:
# 44419

# %% [markdown]
# # Transfer Learning / Fine tuning

# %% [markdown]
# ### Create master train and test splits of the valid image data, with everything in even years used for the training set, and everything in an odd year used for the test split.
# Before doing that, we should check if there are any entries with not valid articleType or year and remove them

# %%
styles.dropna(inplace=True, subset=['year','articleType'])
len(styles)
# Out:
# 44418

# %%
training_data = styles[styles['year'].astype('int') % 2 == 0]
testing_data = styles[styles['year'].astype('int') % 2 == 1]

# %% [markdown]
# ### Creating Fashion Image Dataset class and constructing datasets and dataloaders

# %%
# Check how many unique article types we have
uniquie_article_types = styles['articleType'].unique()
print(len(uniquie_article_types))
# Out:
# 142

# %%
# Create a mapping between article types and their ids
cat_list = uniquie_article_types
cat2num = {cat:i for i, cat in enumerate(cat_list)}
num2cat = {i:cat for i, cat in enumerate(cat_list)}

# %%
# Create data transform
transform = torchvision.transforms.Compose([
                torchvision.transforms.Resize((224, 224)),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
            ])

# %%
# number of subprocesses to use for data loading
num_workers = 8
# how many samples per batch to load
batch_size = 16
# percentage of training set to use as validation
valid_size = 0.2

# %%
# Construct datasets
test_data = FIDataset(os.path.join(DATASET_PATH, 'images'), testing_data, transform, cat2num)
training_dataset = FIDataset(os.path.join(DATASET_PATH, 'images'), training_data, transform, cat2num)

# %%
# split the training data into train and validation datasets
train_sampler, valid_sampler = split_train_valid(training_dataset, valid_size)

# prepare data loaders
train_loader = DataLoader(training_dataset, batch_size=batch_size, 
                                sampler=train_sampler, num_workers=num_workers)
valid_loader = DataLoader(training_dataset, batch_size=batch_size, 
                                sampler=valid_sampler, num_workers=num_workers)

test_loader = DataLoader(test_data, batch_size=batch_size, num_workers=num_workers)

# %% [markdown]
# ### Visualizing sample data from the training dataset

# %%
# Plot sample data from the training dataset of top 20 classes
plot_sample_data(train_loader, 5, num2cat)

# %%
# Plot sample data from the training dataset of the remaining classes
plot_sample_data(test_loader, 5, num2cat)

# %% [markdown]
# ### Find weights in order to handle the problem of imbalanced dataset
# Reference: https://towardsdatascience.com/handling-imbalanced-datasets-in-deep-learning-f48407a0e758
#
# Class balancing techniques play an important role when we actually care about the minority classes.
# In the figure below we can see the distribution of the training data which shows us that the dataset is imbalanced.

# %%
# Group the df by article type and sort in descending order
sorted_df = styles.groupby(['articleType']).size().sort_values(ascending=False)

# %%
# plot the distribution of the whole dataset
plt.rcParams['figure.figsize'] = [20, 5]
sorted_df.plot.bar()
ax1 = plt.axes()
plt.show()
# Out:
# /home/ubuntu/.local/share/virtualenvs/ubuntu-7Wf190Ea/lib/python3.6/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %% [markdown]
# Weight balancing balances our data by altering the weight that each training example carries when computing the loss. Normally, each example and class in our loss function will carry equal weight i.e 1.0. But sometimes we might want certain classes or certain training examples to hold more weight if they are more important. That's what we do in the next step: we assign to each class i the following weight $w_i$:
#
# \begin{equation}
# w_i = \frac{total\_number\_of\_samples}{number\_of\_class\_samples}
# \end{equation}

# %%
# Define the weights for all the 142 classes
total_number_of_samples = np.sum(sorted_df.values)
weights = [total_number_of_samples/sorted_df.values]

# %% [markdown]
# ### Train a classifier network by initializing from a pretrained network (we choose ResNet50 trained on ImageNet)
#
# We will freeze the weights for all of the network except that of the final fully connected layer. This last fully connected layer is replaced with a new one with random weights and only this layer is trained.

# %%
# Check if CUDA is available
use_cuda = torch.cuda.is_available()

# Specify model architecture 
model = models.resnet50(pretrained=True)

# Freeze training for all "features" layers
for param in model.parameters():
    param.requires_grad = False
    
# To reshape the network, we reinitialize the classifier’s linear layer
n_inp = model.fc.in_features
model.fc = nn.Linear(n_inp, len(cat_list))

if use_cuda:
    model = model.cuda()

# %%
# Convert weights vector to a tensor
weights = torch.tensor(weights,  dtype=torch.float)

if use_cuda:
    weights = weights.cuda()

# Specify a loss function and optimizer
criterion = nn.CrossEntropyLoss(weight=weights)

optimizer = optim.SGD(model.fc.parameters(), lr=0.001)

# %%
n_epochs = 20

# train the model
model, train_loss_history, valid_loss_history = train(n_epochs, train_loader, 
                                                      valid_loader, model, optimizer, 
                                                      criterion, use_cuda, 'model_direct2.pt')
# Out:
# Epoch: 1/20 	Training Loss: 3.747489 	Validation Loss: 3.175829
# Validation loss decreased (inf --> 3.175829).  Saving model ...
# Epoch: 2/20 	Training Loss: 2.822253 	Validation Loss: 2.630050
# Validation loss decreased (3.175829 --> 2.630050).  Saving model ...
# Epoch: 3/20 	Training Loss: 2.388978 	Validation Loss: 2.312800
# Validation loss decreased (2.630050 --> 2.312800).  Saving model ...
# Epoch: 4/20 	Training Loss: 2.124933 	Validation Loss: 2.139415
# Validation loss decreased (2.312800 --> 2.139415).  Saving model ...
# Epoch: 5/20 	Training Loss: 1.922213 	Validation Loss: 1.942347
# Validation loss decreased (2.139415 --> 1.942347).  Saving model ...
# Epoch: 6/20 	Training Loss: 1.777527 	Validation Loss: 1.818713
# Validation loss decreased (1.942347 --> 1.818713).  Saving model ...
# Epoch: 7/20 	Training Loss: 1.654925 	Validation Loss: 1.745687
# Validation loss decreased (1.818713 --> 1.745687).  Saving model ...
# Epoch: 8/20 	Training Loss: 1.552461 	Validation Loss: 1.680410
# Validation loss decreased (1.745687 --> 1.680410).  Saving model ...
# Epoch: 9/20 	Training Loss: 1.476453 	Validation Loss: 1.625558
# Validation loss decreased (1.680410 --> 1.625558).  Saving model ...
# Epoch: 10/20 	Training Loss: 1.428350 	Validation Loss: 1.562732
# Validation loss decreased (1.625558 --> 1.562732).  Saving model ...
# Epoch: 11/20 	Training Loss: 1.341632 	Validation Loss: 1.513360
# Validation loss decreased (1.562732 --> 1.513360).  Saving model ...
# Epoch: 12/20 	Training Loss: 1.294283 	Validation Loss: 1.476033
# Validation loss decreased (1.513360 --> 1.476033).  Saving model ...
# Epoch: 13/20 	Training Loss: 1.249026 	Validation Loss: 1.437727
# Validation loss decreased (1.476033 --> 1.437727).  Saving model ...
# Epoch: 14/20 	Training Loss: 1.215252 	Validation Loss: 1.400880
# Validation loss decreased (1.437727 --> 1.400880).  Saving model ...
# Epoch: 15/20 	Training Loss: 1.171744 	Validation Loss: 1.393623
# Validation loss decreased (1.400880 --> 1.393623).  Saving model ...
# Epoch: 16/20 	Training Loss: 1.134953 	Validation Loss: 1.304136
# Validation loss decreased (1.393623 --> 1.304136).  Saving model ...
# Epoch: 17/20 	Training Loss: 1.097062 	Validation Loss: 1.356377
# Epoch: 18/20 	Training Loss: 1.071121 	Validation Loss: 1.291578
# Validation loss decreased (1.304136 --> 1.291578).  Saving model ...
# Epoch: 19/20 	Training Loss: 1.041263 	Validation Loss: 1.303649
# Epoch: 20/20 	Training Loss: 1.032837 	Validation Loss: 1.247432
# Validation loss decreased (1.291578 --> 1.247432).  Saving model ...
# Training complete in 60m 16s

# %%
plot_training_and_valid_loss(train_loss_history, valid_loss_history, n_epochs)

# %% [markdown]
# ### Testing results

# %%
# Load the model that got the best validation accuracy
model.load_state_dict(torch.load('model_direct2.pt'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
plot_sample_data_model(test_loader, 10, model, num2cat, use_cuda=True)

# %%
def test(test_loader, model, criterion, cat_lookup, use_cuda):    
    # initialize lists to monitor correct guesse and total number of data 
    test_loss = 0.0
    class_correct = list(0. for i in range(len(cat_lookup)))
    class_correct_top_5 = list(0. for i in range(len(cat_lookup)))
    class_total = list(0. for i in range(len(cat_lookup)))
    model.eval() # prep model for evaluation

    for data, target in test_loader:
        if use_cuda:
            data, target, model = data.cuda(), target.cuda(), model.cuda()
        #else:
        #    model = model.cpu()
        
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update test loss 
        test_loss += loss.item()*data.size(0)
        
        # get 1 if target in top-1 predictions
        correct_top_1 = correct_top_k(output, target, topk=(1,))
        # get 1 if target in top-5 predictions
        correct_top_5 = correct_top_k(output, target, topk=(5,))
        
        # calculate test accuracy for each object class
        for i in range(len(target)):
            label = target.data[i]
            class_correct[label] += correct_top_1[i].item()
            class_correct_top_5[label] += correct_top_5[i].item()
            class_total[label] += 1
            
    # calculate and print avg test loss
    test_loss = test_loss/len(test_loader.sampler)
    print('Test Loss: {:.6f}\n'.format(test_loss))
    
    class_accuracy_top_1 = {}
    print('\nPrinting accuracy for each class')
    for i in range(len(cat_lookup)):
        if class_total[i] > 0:
            accuracy_top_1 = 100 * class_correct[i] / class_total[i]
            accuracy_top_5 = 100 * class_correct_top_5[i] / class_total[i]
            class_accuracy_top_1[i] = accuracy_top_1
            print('Test accuracy of %5s: \nTop-1 accuracy: %2d%% (%2d/%2d) \nTop-5 accuracy: %2d%% (%2d/%2d)'.format(
            ) % (
                cat_lookup[i], accuracy_top_1,
                np.sum(class_correct[i]), np.sum(class_total[i]),
                 accuracy_top_5, np.sum(class_correct_top_5[i]), np.sum(class_total[i])))
            
            
        else:
            print('Test Accuracy of %5s: N/A (no training examples)' % (cat_lookup[i]))

    print('\nPrinting 5 classes with greatest top-1 accuracy')
    sorted_class_accuracy = sorted(class_accuracy_top_1.items(),  key=lambda kv: kv[1], reverse=True)
    for i in range(5):
        print('Test Accuracy of %5s: %2d%%' % (
            str(cat_lookup[sorted_class_accuracy[i][0]]), sorted_class_accuracy[i][1]))
        
    print('\nTest Accuracy (Overall): \nTop-1 accuracy: %2d%% (%2d/%2d) \nTop-5 accuracy: %2d%% (%2d/%2d)' % (
        100. * np.sum(class_correct) / np.sum(class_total),
        np.sum(class_correct), np.sum(class_total),
         100. * np.sum(class_correct_top_5) / np.sum(class_total),
        np.sum(class_correct_top_5), np.sum(class_total)))

# %%
test(test_loader, model, criterion, cat_lookup=num2cat, use_cuda=True)
# Out:
# Test Loss: 4.077374
#
#
# Printing accuracy for each class
# Test accuracy of Shirts:
# Top-1 accuracy:  0% ( 4/2087)
# Top-5 accuracy: 42% (878/2087)
# Test accuracy of Jeans:
# Top-1 accuracy:  0% ( 0/271)
# Top-5 accuracy:  0% ( 0/271)
# Test accuracy of Watches:
# Top-1 accuracy: 86% (52/60)
# Top-5 accuracy: 100% (60/60)
# Test accuracy of Track Pants:
# Top-1 accuracy:  0% ( 0/173)
# Top-5 accuracy:  0% ( 0/173)
# Test accuracy of Tshirts:
# Top-1 accuracy: 78% (3387/4316)
# Top-5 accuracy: 95% (4132/4316)
# Test accuracy of Socks:
# Top-1 accuracy: 74% (135/181)
# Top-5 accuracy: 93% (170/181)
# Test accuracy of Casual Shoes:
# Top-1 accuracy: 47% (611/1295)
# Top-5 accuracy: 98% (1277/1295)
# Test accuracy of Belts:
# Top-1 accuracy: 81% (263/321)
# Top-5 accuracy: 96% (309/321)
# Test accuracy of Flip Flops:
# Top-1 accuracy: 40% (163/407)
# Top-5 accuracy: 88% (359/407)
# Test accuracy of Handbags:
# Top-1 accuracy: 87% (656/753)
# Top-5 accuracy: 95% (721/753)
# Test accuracy of  Tops:
# Top-1 accuracy: 45% (318/703)
# Top-5 accuracy: 94% (665/703)
# Test accuracy of   Bra:
# Top-1 accuracy:  7% (26/329)
# Top-5 accuracy: 96% (316/329)
# Test accuracy of Sandals:
# Top-1 accuracy: 13% (58/420)
# Top-5 accuracy: 91% (386/420)
# Test accuracy of Shoe Accessories:
# Top-1 accuracy:  0% ( 0/19)
# Top-5 accuracy:  0% ( 0/19)
# Test accuracy of Sweatshirts:
# Top-1 accuracy:  0% ( 0/257)
# Top-5 accuracy:  0% ( 0/257)
# Test accuracy of Deodorant:
# Top-1 accuracy:  0% ( 0/347)
# Top-5 accuracy:  0% ( 0/347)
# Test accuracy of Formal Shoes:
# Top-1 accuracy: 85% (239/278)
# Top-5 accuracy: 99% (277/278)
# Test accuracy of Bracelet:
# Top-1 accuracy:  0% ( 0/21)
# Top-5 accuracy:  0% ( 0/21)
# Test accuracy of Lipstick:
# Top-1 accuracy:  0% ( 0/315)
# Top-5 accuracy:  0% ( 0/315)
# Test accuracy of Flats:
# Top-1 accuracy:  0% ( 0/158)
# Top-5 accuracy: 88% (140/158)
# Test accuracy of Kurtas:
# Top-1 accuracy: 83% (591/704)
# Top-5 accuracy: 99% (703/704)
# Test accuracy of Waistcoat:
# Top-1 accuracy:  0% ( 0/ 6)
# Top-5 accuracy:  0% ( 0/ 6)
# Test accuracy of Sports Shoes:
# Top-1 accuracy: 90% (1043/1155)
# Top-5 accuracy: 99% (1147/1155)
# Test accuracy of Shorts:
# Top-1 accuracy: 33% (71/211)
# Top-5 accuracy: 94% (199/211)
# Test accuracy of Briefs:
# Top-1 accuracy: 91% (172/187)
# Top-5 accuracy: 97% (183/187)
# Test Accuracy of Sarees: N/A (no training examples)
# Test accuracy of Perfume and Body Mist:
# Top-1 accuracy:  0% ( 0/613)
# Top-5 accuracy:  0% ( 0/613)
# Test accuracy of Heels:
# Top-1 accuracy: 90% (494/548)
# Top-5 accuracy: 99% (546/548)
# Test accuracy of Sunglasses:
# Top-1 accuracy: 100% (31/31)
# Top-5 accuracy: 100% (31/31)
# Test accuracy of Innerwear Vests:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy:  0% ( 0/ 1)
# Test accuracy of Pendant:
# Top-1 accuracy:  1% ( 1/81)
# Top-5 accuracy: 85% (69/81)
# Test accuracy of Nail Polish:
# Top-1 accuracy:  0% ( 0/329)
# Top-5 accuracy:  0% ( 0/329)
# Test accuracy of Laptop Bag:
# Top-1 accuracy:  0% ( 0/35)
# Top-5 accuracy:  2% ( 1/35)
# Test accuracy of Scarves:
# Top-1 accuracy: 13% ( 6/46)
# Top-5 accuracy: 73% (34/46)
# Test accuracy of Rain Jacket:
# Top-1 accuracy:  0% ( 0/ 2)
# Top-5 accuracy:  0% ( 0/ 2)
# Test accuracy of Dresses:
# Top-1 accuracy: 74% (69/93)
# Top-5 accuracy: 95% (89/93)
# Test accuracy of Night suits:
# Top-1 accuracy:  7% ( 5/70)
# Top-5 accuracy: 18% (13/70)
# Test accuracy of Skirts:
# Top-1 accuracy:  0% ( 0/53)
# Top-5 accuracy: 56% (30/53)
# Test accuracy of Wallets:
# Top-1 accuracy: 91% (309/336)
# Top-5 accuracy: 99% (335/336)
# Test Accuracy of Blazers: N/A (no training examples)
# Test accuracy of  Ring:
# Top-1 accuracy: 41% (24/58)
# Top-5 accuracy: 96% (56/58)
# Test accuracy of Kurta Sets:
# Top-1 accuracy: 21% ( 7/32)
# Top-5 accuracy: 81% (26/32)
# Test accuracy of Clutches:
# Top-1 accuracy: 70% (51/72)
# Top-5 accuracy: 100% (72/72)
# Test accuracy of Shrug:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy:  0% ( 0/ 1)
# Test accuracy of Backpacks:
# Top-1 accuracy: 95% (456/477)
# Top-5 accuracy: 99% (473/477)
# Test accuracy of  Caps:
# Top-1 accuracy: 85% (112/131)
# Top-5 accuracy: 94% (124/131)
# Test accuracy of Trousers:
# Top-1 accuracy: 94% (246/261)
# Top-5 accuracy: 98% (258/261)
# Test accuracy of Earrings:
# Top-1 accuracy: 83% (68/81)
# Top-5 accuracy: 100% (81/81)
# Test accuracy of Camisoles:
# Top-1 accuracy:  0% ( 0/34)
# Top-5 accuracy:  0% ( 0/34)
# Test Accuracy of Boxers: N/A (no training examples)
# Test accuracy of Jewellery Set:
# Top-1 accuracy: 23% ( 3/13)
# Top-5 accuracy: 100% (13/13)
# Test accuracy of Dupatta:
# Top-1 accuracy:  0% ( 0/ 8)
# Top-5 accuracy: 100% ( 8/ 8)
# Test accuracy of Capris:
# Top-1 accuracy: 57% (30/52)
# Top-5 accuracy: 92% (48/52)
# Test accuracy of Lip Gloss:
# Top-1 accuracy:  0% ( 0/144)
# Top-5 accuracy:  0% ( 0/144)
# Test accuracy of Bath Robe:
# Top-1 accuracy:  0% ( 0/20)
# Top-5 accuracy:  0% ( 0/20)
# Test accuracy of Mufflers:
# Top-1 accuracy:  0% ( 0/29)
# Top-5 accuracy:  0% ( 0/29)
# Test accuracy of Tunics:
# Top-1 accuracy: 17% ( 8/45)
# Top-5 accuracy: 100% (45/45)
# Test accuracy of Jackets:
# Top-1 accuracy: 63% (120/188)
# Top-5 accuracy: 91% (172/188)
# Test Accuracy of Trunk: N/A (no training examples)
# Test accuracy of Lounge Pants:
# Top-1 accuracy:  0% ( 0/19)
# Top-5 accuracy: 42% ( 8/19)
# Test accuracy of Face Wash and Cleanser:
# Top-1 accuracy:  0% ( 0/28)
# Top-5 accuracy:  0% ( 0/28)
# Test accuracy of Necklace and Chains:
# Top-1 accuracy: 92% (37/40)
# Top-5 accuracy: 100% (40/40)
# Test accuracy of Duffel Bag:
# Top-1 accuracy: 45% (21/46)
# Top-5 accuracy: 95% (44/46)
# Test accuracy of Sports Sandals:
# Top-1 accuracy: 50% (15/30)
# Top-5 accuracy: 83% (25/30)
# Test accuracy of Foundation and Primer:
# Top-1 accuracy:  0% ( 0/76)
# Top-5 accuracy:  0% ( 0/76)
# Test accuracy of Sweaters:
# Top-1 accuracy:  1% ( 4/255)
# Top-5 accuracy: 62% (160/255)
# Test accuracy of Free Gifts:
# Top-1 accuracy:  0% ( 0/12)
# Top-5 accuracy: 41% ( 5/12)
# Test Accuracy of Trolley Bag: N/A (no training examples)
# Test accuracy of Tracksuits:
# Top-1 accuracy:  0% ( 0/20)
# Top-5 accuracy:  0% ( 0/20)
# Test accuracy of Swimwear:
# Top-1 accuracy:  0% ( 0/ 8)
# Top-5 accuracy: 12% ( 1/ 8)
# Test accuracy of Shoe Laces:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy:  0% ( 0/ 1)
# Test accuracy of Fragrance Gift Set:
# Top-1 accuracy:  0% ( 0/57)
# Top-5 accuracy:  0% ( 0/57)
# Test accuracy of Bangle:
# Top-1 accuracy: 47% (11/23)
# Top-5 accuracy: 91% (21/23)
# Test accuracy of Nightdress:
# Top-1 accuracy:  0% ( 1/160)
# Top-5 accuracy: 68% (109/160)
# Test accuracy of  Ties:
# Top-1 accuracy: 97% (81/83)
# Top-5 accuracy: 98% (82/83)
# Test accuracy of Baby Dolls:
# Top-1 accuracy:  0% ( 0/16)
# Top-5 accuracy:  0% ( 0/16)
# Test accuracy of Leggings:
# Top-1 accuracy: 54% (26/48)
# Top-5 accuracy: 100% (48/48)
# Test accuracy of Highlighter and Blush:
# Top-1 accuracy:  0% ( 0/53)
# Top-5 accuracy:  0% ( 0/53)
# Test accuracy of Travel Accessory:
# Top-1 accuracy:  0% ( 0/10)
# Top-5 accuracy:  0% ( 0/10)
# Test accuracy of Kurtis:
# Top-1 accuracy: 42% (37/88)
# Top-5 accuracy: 98% (87/88)
# Test accuracy of Mobile Pouch:
# Top-1 accuracy: 11% ( 2/18)
# Top-5 accuracy: 77% (14/18)
# Test accuracy of Messenger Bag:
# Top-1 accuracy:  8% ( 2/24)
# Top-5 accuracy: 83% (20/24)
# Test accuracy of Lip Care:
# Top-1 accuracy:  0% ( 0/16)
# Top-5 accuracy:  0% ( 0/16)
# Test accuracy of Face Moisturisers:
# Top-1 accuracy:  0% ( 0/61)
# Top-5 accuracy:  0% ( 0/61)
# Test accuracy of Compact:
# Top-1 accuracy:  0% ( 0/49)
# Top-5 accuracy:  0% ( 0/49)
# Test accuracy of Eye Cream:
# Top-1 accuracy:  0% ( 0/ 6)
# Top-5 accuracy:  0% ( 0/ 6)
# Test accuracy of Accessory Gift Set:
# Top-1 accuracy: 81% (68/83)
# Top-5 accuracy: 98% (82/83)
# Test accuracy of Beauty Accessory:
# Top-1 accuracy:  0% ( 0/ 4)
# Top-5 accuracy:  0% ( 0/ 4)
# Test accuracy of Jumpsuit:
# Top-1 accuracy:  0% ( 0/ 2)
# Top-5 accuracy:  0% ( 0/ 2)
# Test accuracy of Kajal and Eyeliner:
# Top-1 accuracy:  0% ( 0/102)
# Top-5 accuracy:  0% ( 0/102)
# Test accuracy of Water Bottle:
# Top-1 accuracy: 100% ( 1/ 1)
# Top-5 accuracy: 100% ( 1/ 1)
# Test Accuracy of Suspenders: N/A (no training examples)
# Test accuracy of Lip Liner:
# Top-1 accuracy:  0% ( 0/48)
# Top-5 accuracy:  0% ( 0/48)
# Test accuracy of  Robe:
# Top-1 accuracy:  0% ( 0/ 3)
# Top-5 accuracy:  0% ( 0/ 3)
# Test Accuracy of Salwar and Dupatta: N/A (no training examples)
# Test Accuracy of Patiala: N/A (no training examples)
# Test accuracy of Stockings:
# Top-1 accuracy: 11% ( 2/17)
# Top-5 accuracy: 58% (10/17)
# Test accuracy of Eyeshadow:
# Top-1 accuracy:  0% ( 0/42)
# Top-5 accuracy:  0% ( 0/42)
# Test accuracy of Headband:
# Top-1 accuracy:  0% ( 0/ 3)
# Top-5 accuracy: 33% ( 1/ 3)
# Test accuracy of Tights:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy:  0% ( 0/ 1)
# Test accuracy of Nail Essentials:
# Top-1 accuracy:  0% ( 0/ 6)
# Top-5 accuracy:  0% ( 0/ 6)
# Test accuracy of Churidar:
# Top-1 accuracy: 50% ( 2/ 4)
# Top-5 accuracy: 100% ( 4/ 4)
# Test Accuracy of Lounge Tshirts: N/A (no training examples)
# Test accuracy of Face Scrub and Exfoliator:
# Top-1 accuracy:  0% ( 0/ 5)
# Top-5 accuracy:  0% ( 0/ 5)
# Test accuracy of Lounge Shorts:
# Top-1 accuracy:  0% ( 0/ 9)
# Top-5 accuracy: 33% ( 3/ 9)
# Test accuracy of Gloves:
# Top-1 accuracy: 16% ( 1/ 6)
# Top-5 accuracy: 83% ( 5/ 6)
# Test accuracy of Mask and Peel:
# Top-1 accuracy:  0% ( 0/12)
# Top-5 accuracy:  0% ( 0/12)
# Test accuracy of Wristbands:
# Top-1 accuracy:  0% ( 0/ 4)
# Top-5 accuracy:  0% ( 0/ 4)
# Test Accuracy of Tablet Sleeve: N/A (no training examples)
# Test accuracy of Ties and Cufflinks:
# Top-1 accuracy:  0% ( 0/ 2)
# Top-5 accuracy:  0% ( 0/ 2)
# Test accuracy of Footballs:
# Top-1 accuracy: 100% ( 2/ 2)
# Top-5 accuracy: 100% ( 2/ 2)
# Test accuracy of Stoles:
# Top-1 accuracy: 40% ( 4/10)
# Top-5 accuracy: 70% ( 7/10)
# Test accuracy of Shapewear:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy: 100% ( 1/ 1)
# Test Accuracy of Nehru Jackets: N/A (no training examples)
# Test Accuracy of Salwar: N/A (no training examples)
# Test accuracy of Cufflinks:
# Top-1 accuracy: 83% (25/30)
# Top-5 accuracy: 100% (30/30)
# Test Accuracy of Jeggings: N/A (no training examples)
# Test accuracy of Hair Colour:
# Top-1 accuracy:  0% ( 0/19)
# Top-5 accuracy:  0% ( 0/19)
# Test accuracy of Concealer:
# Top-1 accuracy:  0% ( 0/11)
# Top-5 accuracy:  0% ( 0/11)
# Test Accuracy of Rompers: N/A (no training examples)
# Test accuracy of Body Lotion:
# Top-1 accuracy:  0% ( 0/ 6)
# Top-5 accuracy:  0% ( 0/ 6)
# Test accuracy of Sunscreen:
# Top-1 accuracy:  0% ( 0/25)
# Top-5 accuracy:  0% ( 0/25)
# Test Accuracy of Booties: N/A (no training examples)
# Test accuracy of Waist Pouch:
# Top-1 accuracy:  0% ( 0/13)
# Top-5 accuracy:  0% ( 0/13)
# Test Accuracy of Hair Accessory: N/A (no training examples)
# Test accuracy of Rucksacks:
# Top-1 accuracy:  0% ( 0/ 8)
# Top-5 accuracy: 87% ( 7/ 8)
# Test accuracy of Basketballs:
# Top-1 accuracy:  0% ( 0/11)
# Top-5 accuracy:  0% ( 0/11)
# Test Accuracy of Lehenga Choli: N/A (no training examples)
# Test Accuracy of Clothing Set: N/A (no training examples)
# Test accuracy of Mascara:
# Top-1 accuracy:  0% ( 0/13)
# Top-5 accuracy:  0% ( 0/13)
# Test accuracy of Toner:
# Top-1 accuracy:  0% ( 0/ 5)
# Top-5 accuracy:  0% ( 0/ 5)
# Test Accuracy of Cushion Covers: N/A (no training examples)
# Test accuracy of Key chain:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy:  0% ( 0/ 1)
# Test accuracy of Makeup Remover:
# Top-1 accuracy:  0% ( 0/ 3)
# Top-5 accuracy:  0% ( 0/ 3)
# Test accuracy of Lip Plumper:
# Top-1 accuracy:  0% ( 0/ 4)
# Top-5 accuracy:  0% ( 0/ 4)
# Test accuracy of Umbrellas:
# Top-1 accuracy:  0% ( 0/ 5)
# Top-5 accuracy:  0% ( 0/ 5)
# Test accuracy of Face Serum and Gel:
# Top-1 accuracy:  0% ( 0/ 2)
# Top-5 accuracy:  0% ( 0/ 2)
# Test accuracy of   Hat:
# Top-1 accuracy:  0% ( 0/ 3)
# Top-5 accuracy:  0% ( 0/ 3)
# Test accuracy of Mens Grooming Kit:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy:  0% ( 0/ 1)
# Test accuracy of Rain Trousers:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy:  0% ( 0/ 1)
# Test accuracy of Body Wash and Scrub:
# Top-1 accuracy:  0% ( 0/ 1)
# Top-5 accuracy:  0% ( 0/ 1)
# Test Accuracy of  Ipad: N/A (no training examples)
#
# Printing 5 classes with greatest top-1 accuracy
# Test Accuracy of Sunglasses: 100%
# Test Accuracy of Water Bottle: 100%
# Test Accuracy of Footballs: 100%
# Test Accuracy of  Ties: 97%
# Test Accuracy of Backpacks: 95%
#
# Test Accuracy (Overall):
# Top-1 accuracy: 49% (10171/20634)
# Top-5 accuracy: 73% (15263/20634)
