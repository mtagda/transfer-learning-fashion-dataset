# %%
import os
import torch
import torchvision
import numpy as np
import pandas as pd
from PIL import Image
from torch import optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data.sampler import SubsetRandomSampler
import time
from model_utils import *
from pytorch_helpers import *

# %matplotlib inline

# %% [markdown]
# # Explore and clean the data
# In this section, we want to explore the data and prepare for image classification.

# %%
# create a df from styles.csv neglecting lines with error
DATASET_PATH = '/mnt/fashion-dataset-1/fashion-dataset/'
styles = pd.read_csv(os.path.join(DATASET_PATH, "styles.csv"), error_bad_lines=False)
# Out:
# b'Skipping line 6044: expected 10 fields, saw 11\nSkipping line 6569: expected 10 fields, saw 11\nSkipping line 7399: expected 10 fields, saw 11\nSkipping line 7939: expected 10 fields, saw 11\nSkipping line 9026: expected 10 fields, saw 11\nSkipping line 10264: expected 10 fields, saw 11\nSkipping line 10427: expected 10 fields, saw 11\nSkipping line 10905: expected 10 fields, saw 11\nSkipping line 11373: expected 10 fields, saw 11\nSkipping line 11945: expected 10 fields, saw 11\nSkipping line 14112: expected 10 fields, saw 11\nSkipping line 14532: expected 10 fields, saw 11\nSkipping line 15076: expected 10 fields, saw 12\nSkipping line 29906: expected 10 fields, saw 11\nSkipping line 31625: expected 10 fields, saw 11\nSkipping line 33020: expected 10 fields, saw 11\nSkipping line 35748: expected 10 fields, saw 11\nSkipping line 35962: expected 10 fields, saw 11\nSkipping line 37770: expected 10 fields, saw 11\nSkipping line 38105: expected 10 fields, saw 11\nSkipping line 38275: expected 10 fields, saw 11\nSkipping line 38404: expected 10 fields, saw 12\n'

# %%
print(styles.head())
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
print(len(styles))
# Out:
# 44424

# %%
# Get the list of names of images that are available
imgs_available = os.listdir(DATASET_PATH + '/images')
print(len(imgs_available))
# Out:
# 44442

# %% [markdown]
# We want to check if each entry in styles.csv has a corresponding images listing. If not, we remove it from the dataframe.

# %%
# Check if each entry in styles.csv has a corresponding images listing. 
# If not, we remove it from the dataframe.
missing_img = []
for idx, line in styles.iterrows():
    if not os.path.exists(os.path.join(DATASET_PATH, 'images', str(line.id)+'.jpg')):
        print(os.path.join(DATASET_PATH, 'images', str(line.id)+'.jpg'))
        missing_img.append(idx)
        
styles.drop(styles.index[missing_img], inplace=True)
# Out:
# /mnt/fashion-dataset-1/fashion-dataset/images/39403.jpg
# /mnt/fashion-dataset-1/fashion-dataset/images/39410.jpg
# /mnt/fashion-dataset-1/fashion-dataset/images/39401.jpg
# /mnt/fashion-dataset-1/fashion-dataset/images/39425.jpg
# /mnt/fashion-dataset-1/fashion-dataset/images/12347.jpg

# %%
print(len(styles))
# Out:
# 44419

# %% [markdown]
# ## Getting the top articleTypes

# %%
# Check how many unique article types we have
uniquie_article_types = styles['articleType'].unique()
print(len(uniquie_article_types))
# Out:
# 142

# %% [markdown]
# There are 142 distinct articleTypes. In the next cell we are going to see what are the top 20 of them.

# %%
sorted_df = styles.groupby(['articleType']).size().sort_values(ascending=False)
top_classes = sorted_df.nlargest(20)
display(top_classes)
# Out:
# articleType
# Tshirts                  7066
# Shirts                   3215
# Casual Shoes             2845
# Watches                  2542
# Sports Shoes             2036
# Kurtas                   1844
# Tops                     1762
# Handbags                 1759
# Heels                    1323
# Sunglasses               1073
# Wallets                   936
# Flip Flops                914
# Sandals                   897
# Briefs                    849
# Belts                     813
# Backpacks                 724
# Socks                     686
# Formal Shoes              637
# Perfume and Body Mist     613
# Jeans                     608
# dtype: int64

# %%
# plot the distribution of top 20 classes
top_classes.plot.bar()

# %% [markdown]
# # Transfer Learning / Fine tuning

# %% [markdown]
# ### Create master train and test splits of the valid image data, with everything in even years used for the training set, and everything in an odd year used for the test split.
# Before doing that, we should check if there are any entries with not valid articleType or year and remove them

# %%
styles.dropna(inplace=True, subset=['year','articleType'])
len(styles)
# Out:
# 44418

# %%
training_data = styles[styles['year'].astype('int') % 2 == 0]
testing_data = styles[styles['year'].astype('int') % 2 == 1]

# %% [markdown]
# ### Create sub-splits of the training data for pre-training and fine tuning
# We will do it as follows:
# * the top 20 classes (see above) - about 3/4 of the data; and
# * all other classes - about 1/4 of the data

# %%
top_classes_names = list(top_classes.index)

# %%
training_top20 = training_data[training_data.articleType.isin(top_classes_names)]
testing_top20 = testing_data[testing_data.articleType.isin(top_classes_names)]

# %% [markdown]
# ### Find weights in order to handle the problem of imbalanced dataset
# Reference: https://towardsdatascience.com/handling-imbalanced-datasets-in-deep-learning-f48407a0e758
# Class balancing techniques play an important role when we actually care about the minority classes. In the figure above we can see the distribution of the training data which shows us that the dataset is imbalanced.
#
# Weight balancing balances our data by altering the weight that each training example carries when computing the loss. Normally, each example and class in our loss function will carry equal weight i.e 1.0. But sometimes we might want certain classes or certain training examples to hold more weight if they are more important. That's what we do in the next step: we assign to each class i the following weight $w_i$:
#
# \begin{equation}
# w_i = \frac{total\_number\_of\_samples}{number\_of\_class\_samples}
# \end{equation}

# %%
# Find weights 
total_number_of_samples = np.sum(top_classes.values)
weights = [total_number_of_samples/top_classes.values]

# %% [markdown]
# ### Constructing datasets and dataloaders

# %%
# Create a mapping between article types and their ids
cat_list = sorted_df.index
cat2num = {cat:i for i, cat in enumerate(cat_list)}
num2cat = {i:cat for i, cat in enumerate(cat_list)}

# %%
# Create data transform
transform = torchvision.transforms.Compose([
                torchvision.transforms.Resize((224, 224)),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
            ])

# %%
# number of subprocesses to use for data loading
num_workers = 8
# how many samples per batch to load
batch_size = 16
# percentage of training set to use as validation
valid_size = 0.2

# %%
# Construct datasets
top20_data = FIDataset(os.path.join(DATASET_PATH, 'images'), training_top20, transform, cat2num)
# others_data = FIDataset(os.path.join(DATASET_PATH, 'images'), training_others, transform, cat2num)

test_top20 = FIDataset(os.path.join(DATASET_PATH, 'images'), testing_top20, transform, cat2num)

# %%
# split the training data for 'top 20' classes into train and validation datasets
top20_train_sampler, top20_valid_sampler = split_train_valid(top20_data, valid_size)

# prepare data loaders
top20_train_loader = DataLoader(top20_data, batch_size=batch_size, 
                                sampler=top20_train_sampler, num_workers=num_workers)
top20_valid_loader = DataLoader(top20_data, batch_size=batch_size, 
                                sampler=top20_valid_sampler, num_workers=num_workers)
top20_test_loader = DataLoader(test_top20, batch_size=batch_size, num_workers=num_workers)

# %% [markdown]
# ### Visualizing sample data from the training dataset

# %%
# Plot sample data from the training dataset of top 20 classes
plot_sample_data(top20_train_loader, 5, num2cat)

# %%
# Plot sample data from the training dataset of the remaining classes
plot_sample_data(top20_test_loader, 5, num2cat)

# %% [markdown]
# ### Train a classifier network by initializing from a pretrained network (we choose ResNet50 trained on ImageNet) and retraining the weights of the whole network.

# %%
# Check if CUDA is available
use_cuda = torch.cuda.is_available()

# Specify model architecture 
model_top20 = models.resnet50(pretrained=True)

# To reshape the network, we reinitialize the classifier’s linear layer
n_inp = model_top20.fc.in_features
model_top20.fc = nn.Linear(n_inp, len(top_classes_names))

if use_cuda:
    model_top20 = model_top20.cuda()

# %%
print(model_top20.fc)
# Out:
# Linear(in_features=2048, out_features=20, bias=True)

# %%
# Convert weights vector to a tensor
weights = torch.tensor(weights,  dtype=torch.float)

if use_cuda:
    weights = weights.cuda()

# Specify a loss function and optimizer
criterion = nn.CrossEntropyLoss(weight=weights)

optimizer = optim.SGD(model_top20.parameters(), lr=0.001)

# %%
n_epochs = 20

# train the model
model_top20, train_loss_history_top20, valid_loss_history_top20 = train(n_epochs, top20_train_loader, 
                                                      top20_valid_loader, model_top20, optimizer, 
                                                      criterion, use_cuda, 'model_top20.pt')
# Out:
# Epoch: 1/20 	Training Loss: 1.282063 	Validation Loss: 0.465129
# Validation loss decreased (inf --> 0.465129).  Saving model ...
# Epoch: 2/20 	Training Loss: 0.432186 	Validation Loss: 0.268926
# Validation loss decreased (0.465129 --> 0.268926).  Saving model ...
# Epoch: 3/20 	Training Loss: 0.288576 	Validation Loss: 0.224760
# Validation loss decreased (0.268926 --> 0.224760).  Saving model ...
# Epoch: 4/20 	Training Loss: 0.228203 	Validation Loss: 0.190162
# Validation loss decreased (0.224760 --> 0.190162).  Saving model ...
# Epoch: 5/20 	Training Loss: 0.186361 	Validation Loss: 0.180894
# Validation loss decreased (0.190162 --> 0.180894).  Saving model ...
# Epoch: 6/20 	Training Loss: 0.156727 	Validation Loss: 0.165075
# Validation loss decreased (0.180894 --> 0.165075).  Saving model ...
# Epoch: 7/20 	Training Loss: 0.136485 	Validation Loss: 0.160109
# Validation loss decreased (0.165075 --> 0.160109).  Saving model ...
# Epoch: 8/20 	Training Loss: 0.121992 	Validation Loss: 0.153523
# Validation loss decreased (0.160109 --> 0.153523).  Saving model ...
# Epoch: 9/20 	Training Loss: 0.107489 	Validation Loss: 0.158626
# Epoch: 10/20 	Training Loss: 0.094738 	Validation Loss: 0.153175
# Validation loss decreased (0.153523 --> 0.153175).  Saving model ...
# Epoch: 11/20 	Training Loss: 0.083954 	Validation Loss: 0.155278
# Epoch: 12/20 	Training Loss: 0.078666 	Validation Loss: 0.150242
# Validation loss decreased (0.153175 --> 0.150242).  Saving model ...
# Epoch: 13/20 	Training Loss: 0.066397 	Validation Loss: 0.156959
# Epoch: 14/20 	Training Loss: 0.058126 	Validation Loss: 0.159138
# Epoch: 15/20 	Training Loss: 0.053719 	Validation Loss: 0.162280
# Epoch: 16/20 	Training Loss: 0.049893 	Validation Loss: 0.156702
# Epoch: 17/20 	Training Loss: 0.043518 	Validation Loss: 0.159866
# Epoch: 18/20 	Training Loss: 0.038173 	Validation Loss: 0.164894
# Epoch: 19/20 	Training Loss: 0.034794 	Validation Loss: 0.164512
# Epoch: 20/20 	Training Loss: 0.029450 	Validation Loss: 0.165662
# Training complete in 119m 10s

# %%
plot_training_and_valid_loss(train_loss_history_top20, valid_loss_history_top20, n_epochs)

# %% [markdown]
# ### Testing results

# %%
# Load the model that got the best validation accuracy
model_top20.load_state_dict(torch.load('model_top20.pt'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
plot_sample_data_model(top20_test_loader, 10, model_top20, num2cat, use_cuda=True)

# %%
top20_cat_lookup = {i:j for i, j in num2cat.items() if j in top_classes_names}
test(top20_test_loader, model_top20, criterion, cat_lookup=top20_cat_lookup, use_cuda=True)
# Out:
# Test Loss: 1.071835
#
# Printing 5 classes with greatest accuracy
# Test Accuracy of Watches: 100%
# Test Accuracy of Sunglasses: 100%
# Test Accuracy of Jeans: 99%
# Test Accuracy of Shirts: 99%
# Test Accuracy of Belts: 98%
#
# Printing accuracy for each class
# Test Accuracy of Watches: 89% (3876/4316)
# Test Accuracy of Sunglasses: 99% (2068/2087)
# Test Accuracy of Jeans: 78% (1016/1295)
# Test Accuracy of Shirts: 100% (60/60)
# Test Accuracy of Belts: 86% (994/1155)
# Test Accuracy of Kurtas: 98% (690/704)
# Test Accuracy of Wallets: 82% (581/703)
# Test Accuracy of Backpacks: 96% (723/753)
# Test Accuracy of Formal Shoes: 93% (515/548)
# Test Accuracy of Socks: 100% (31/31)
# Test Accuracy of Handbags: 97% (329/336)
# Test Accuracy of Briefs: 85% (349/407)
# Test Accuracy of Heels: 80% (339/420)
# Test Accuracy of Tshirts: 95% (179/187)
# Test Accuracy of Sports Shoes: 98% (315/321)
# Test Accuracy of Flip Flops: 97% (467/477)
# Test Accuracy of  Tops: 96% (174/181)
# Test Accuracy of Sandals: 96% (268/278)
# Test Accuracy of Casual Shoes:  0% ( 0/613)
# Test Accuracy of Perfume and Body Mist: 99% (269/271)
#
# Test Accuracy (Overall): 87% (13243/15143)

# %% [markdown]
# # Fine tuning the model

# %% [markdown]
# ### Constructing datasets and dataloaders

# %%
# Construct datasets
test_data = FIDataset(os.path.join(DATASET_PATH, 'images'), testing_data, transform, cat2num)
training_dataset = FIDataset(os.path.join(DATASET_PATH, 'images'), training_data, transform, cat2num)

# split the training data into train and validation datasets
train_sampler, valid_sampler = split_train_valid(training_dataset, valid_size)

# prepare data loaders
train_loader = DataLoader(training_dataset, batch_size=batch_size, 
                                sampler=train_sampler, num_workers=num_workers)
valid_loader = DataLoader(training_dataset, batch_size=batch_size, 
                                sampler=valid_sampler, num_workers=num_workers)

test_loader = DataLoader(test_data, batch_size=batch_size, num_workers=num_workers)

# %% [markdown]
# ### Visualizing sample data from the training dataset

# %%
# Plot sample data from the training dataset of top 20 classes
plot_sample_data(train_loader, 5, num2cat)

# %%
# Plot sample data from the training dataset of top 20 classes
plot_sample_data(test_loader, 5, num2cat)

# %% [markdown]
# ### Fine tuning
#
# Replace the 20-class FC layer with a 142-class output layer. Freeze the initial 5 layers of the pretrained model (model_top20) and train just the remaining layers again. The top layers would then be customized to the new data set. Since the new data set contains 122 new classes with low similarity, it is a good idea to retrain and customize the higher layers according to the new dataset. The initial layers are kept pretrained and the weights for those layers are frozen.

# %%
model_142 = model_top20

# Freeze the first 5 layers of the model
layers_to_freeze=5
layer_count=0

print('Layers to freeze: \n')
for child in model_142.children():
    layer_count+=1
    if layer_count <= layers_to_freeze:
        print(child)
        for param in child.parameters():
            param.requires_grad = False
# Out:
# Layers to freeze:
#
# Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ReLU(inplace)
# MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Sequential(
#   (0): Bottleneck(
#     (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (downsample): Sequential(
#       (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Bottleneck(
#     (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#   )
#   (2): Bottleneck(
#     (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#   )
# )

# %%
# To reshape the network, we reinitialize the classifier’s linear layer
n_inp = model_142.fc.in_features
model_142.fc = nn.Linear(n_inp, len(uniquie_article_types))

if use_cuda:
    model_142 = model_142.cuda()

# %%
# Define the weights for all the 142 classes as before
total_number_of_samples = np.sum(sorted_df.values)
weights = [total_number_of_samples/sorted_df.values]

# %%
# Convert weights vector to a tensor
weights = torch.tensor(weights,  dtype=torch.float)

if use_cuda:
    weights = weights.cuda()

# Specify a loss function and optimizer
criterion = nn.CrossEntropyLoss(weight=weights)

optimizer = optim.SGD(model_142.parameters(), lr=0.001)

# %% [markdown]
# ### Training the model

# %%
n_epochs = 20

# train the model
model_142, train_loss_history_142, valid_loss_history_142 = train(n_epochs, train_loader, 
                                                      valid_loader, model_142, optimizer, 
                                                      criterion, use_cuda, 'model_142.pt')
# Out:
# Epoch: 1/20 	Training Loss: 3.035501 	Validation Loss: 2.020451
# Validation loss decreased (inf --> 2.020451).  Saving model ...
# Epoch: 2/20 	Training Loss: 1.675990 	Validation Loss: 1.485136
# Validation loss decreased (2.020451 --> 1.485136).  Saving model ...
# Epoch: 3/20 	Training Loss: 1.176235 	Validation Loss: 1.197806
# Validation loss decreased (1.485136 --> 1.197806).  Saving model ...
# Epoch: 4/20 	Training Loss: 0.905283 	Validation Loss: 1.090839
# Validation loss decreased (1.197806 --> 1.090839).  Saving model ...
# Epoch: 5/20 	Training Loss: 0.725278 	Validation Loss: 0.946850
# Validation loss decreased (1.090839 --> 0.946850).  Saving model ...
# Epoch: 6/20 	Training Loss: 0.585776 	Validation Loss: 0.897527
# Validation loss decreased (0.946850 --> 0.897527).  Saving model ...
# Epoch: 7/20 	Training Loss: 0.483810 	Validation Loss: 0.901888
# Epoch: 8/20 	Training Loss: 0.394594 	Validation Loss: 0.824432
# Validation loss decreased (0.897527 --> 0.824432).  Saving model ...
# Epoch: 9/20 	Training Loss: 0.336938 	Validation Loss: 0.789734
# Validation loss decreased (0.824432 --> 0.789734).  Saving model ...
# Epoch: 10/20 	Training Loss: 0.281059 	Validation Loss: 0.903260
# Epoch: 11/20 	Training Loss: 0.238697 	Validation Loss: 0.819878
# Epoch: 12/20 	Training Loss: 0.208232 	Validation Loss: 0.850355
# Epoch: 13/20 	Training Loss: 0.181503 	Validation Loss: 0.878988
# Epoch: 14/20 	Training Loss: 0.154307 	Validation Loss: 0.919546
# Epoch: 15/20 	Training Loss: 0.136064 	Validation Loss: 0.873363
# Epoch: 16/20 	Training Loss: 0.118908 	Validation Loss: 0.923336
# Epoch: 17/20 	Training Loss: 0.103946 	Validation Loss: 0.997601
# Epoch: 18/20 	Training Loss: 0.093706 	Validation Loss: 0.957496
# Epoch: 19/20 	Training Loss: 0.082716 	Validation Loss: 0.931234
# Epoch: 20/20 	Training Loss: 0.073780 	Validation Loss: 0.934888
# Training complete in 130m 27s

# %%
plot_training_and_valid_loss(train_loss_history_142, valid_loss_history_142, n_epochs)

# %% [markdown]
# ### Testing results

# %%
plot_sample_data_model(test_loader, 10, model_142, num2cat, use_cuda=True)

# %%
# Load the model that got the best validation accuracy
model_142.load_state_dict(torch.load('model_142.pt'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
test(test_loader, model_142, criterion, cat_lookup=num2cat, use_cuda=True)
# Out:
# Test Loss: 4.562591
#
#
# Printing accuracy for each class
# Test Accuracy of Tshirts: 86% (3724/4316)
# Test Accuracy of Shirts: 96% (2015/2087)
# Test Accuracy of Casual Shoes: 78% (1012/1295)
# Test Accuracy of Watches: 98% (59/60)
# Test Accuracy of Sports Shoes: 86% (998/1155)
# Test Accuracy of Kurtas: 89% (631/704)
# Test Accuracy of  Tops: 59% (417/703)
# Test Accuracy of Handbags: 86% (653/753)
# Test Accuracy of Heels: 55% (302/548)
# Test Accuracy of Sunglasses: 100% (31/31)
# Test Accuracy of Wallets: 94% (316/336)
# Test Accuracy of Flip Flops: 85% (348/407)
# Test Accuracy of Sandals: 64% (269/420)
# Test Accuracy of Briefs: 96% (180/187)
# Test Accuracy of Belts: 99% (318/321)
# Test Accuracy of Backpacks: 97% (464/477)
# Test Accuracy of Socks: 96% (174/181)
# Test Accuracy of Formal Shoes: 93% (259/278)
# Test Accuracy of Perfume and Body Mist:  0% ( 0/613)
# Test Accuracy of Jeans: 79% (215/271)
# Test Accuracy of Shorts: 82% (174/211)
# Test Accuracy of Trousers: 90% (237/261)
# Test Accuracy of Flats: 62% (98/158)
# Test Accuracy of   Bra: 98% (324/329)
# Test Accuracy of Dresses: 89% (83/93)
# Test Accuracy of Sarees: N/A (no training examples)
# Test Accuracy of Earrings: 100% (81/81)
# Test Accuracy of Deodorant:  0% ( 0/347)
# Test Accuracy of Nail Polish:  0% ( 0/329)
# Test Accuracy of Lipstick:  0% ( 0/315)
# Test Accuracy of Track Pants: 82% (142/173)
# Test Accuracy of Clutches: 95% (69/72)
# Test Accuracy of Sweatshirts:  7% (19/257)
# Test Accuracy of  Caps: 91% (120/131)
# Test Accuracy of Sweaters:  2% ( 6/255)
# Test Accuracy of  Ties: 98% (82/83)
# Test Accuracy of Jackets: 54% (102/188)
# Test Accuracy of Innerwear Vests:  0% ( 0/ 1)
# Test Accuracy of Kurtis: 50% (44/88)
# Test Accuracy of Tunics: 37% (17/45)
# Test Accuracy of Nightdress:  1% ( 2/160)
# Test Accuracy of Leggings: 50% (24/48)
# Test Accuracy of Pendant: 86% (70/81)
# Test Accuracy of Capris: 65% (34/52)
# Test Accuracy of Necklace and Chains: 92% (37/40)
# Test Accuracy of Lip Gloss:  0% ( 0/144)
# Test Accuracy of Night suits: 75% (53/70)
# Test Accuracy of Trunk: N/A (no training examples)
# Test Accuracy of Skirts: 60% (32/53)
# Test Accuracy of Scarves: 82% (38/46)
# Test Accuracy of  Ring: 81% (47/58)
# Test Accuracy of Dupatta:  0% ( 0/ 8)
# Test Accuracy of Cufflinks: 96% (29/30)
# Test Accuracy of Kajal and Eyeliner:  0% ( 0/102)
# Test Accuracy of Accessory Gift Set: 100% (83/83)
# Test Accuracy of Kurta Sets: 96% (31/32)
# Test Accuracy of Free Gifts:  0% ( 0/12)
# Test Accuracy of Stoles: 30% ( 3/10)
# Test Accuracy of Duffel Bag: 76% (35/46)
# Test Accuracy of Bangle: 26% ( 6/23)
# Test Accuracy of Laptop Bag: 42% (15/35)
# Test Accuracy of Foundation and Primer:  0% ( 0/76)
# Test Accuracy of Sports Sandals: 60% (18/30)
# Test Accuracy of Bracelet: 66% (14/21)
# Test Accuracy of Face Moisturisers:  0% ( 0/61)
# Test Accuracy of Lounge Pants: 21% ( 4/19)
# Test Accuracy of Jewellery Set: 69% ( 9/13)
# Test Accuracy of Fragrance Gift Set:  0% ( 0/57)
# Test Accuracy of Highlighter and Blush:  0% ( 0/53)
# Test Accuracy of Boxers: N/A (no training examples)
# Test Accuracy of Compact:  0% ( 0/49)
# Test Accuracy of Lip Liner:  0% ( 0/48)
# Test Accuracy of Mobile Pouch: 38% ( 7/18)
# Test Accuracy of Messenger Bag: 66% (16/24)
# Test Accuracy of Eyeshadow:  0% ( 0/42)
# Test Accuracy of Suspenders: N/A (no training examples)
# Test Accuracy of Camisoles:  0% ( 0/34)
# Test Accuracy of Mufflers:  0% ( 0/29)
# Test Accuracy of Patiala: N/A (no training examples)
# Test Accuracy of Lounge Shorts:  0% ( 0/ 9)
# Test Accuracy of Jeggings: N/A (no training examples)
# Test Accuracy of Salwar: N/A (no training examples)
# Test Accuracy of Stockings: 52% ( 9/17)
# Test Accuracy of Churidar: 50% ( 2/ 4)
# Test Accuracy of Tracksuits: 80% (16/20)
# Test Accuracy of Face Wash and Cleanser:  0% ( 0/28)
# Test Accuracy of Sunscreen:  0% ( 0/25)
# Test Accuracy of Shoe Accessories:  0% ( 0/19)
# Test Accuracy of Gloves: 50% ( 3/ 6)
# Test Accuracy of Bath Robe:  0% ( 0/20)
# Test Accuracy of Hair Colour:  0% ( 0/19)
# Test Accuracy of Rain Jacket: 100% ( 2/ 2)
# Test Accuracy of Swimwear: 37% ( 3/ 8)
# Test Accuracy of Waist Pouch:  0% ( 0/13)
# Test Accuracy of Travel Accessory: 10% ( 1/10)
# Test Accuracy of Lip Care:  0% ( 0/16)
# Test Accuracy of Baby Dolls:  0% ( 0/16)
# Test Accuracy of Jumpsuit: 50% ( 1/ 2)
# Test Accuracy of Waistcoat:  0% ( 0/ 6)
# Test Accuracy of Basketballs:  9% ( 1/11)
# Test Accuracy of Mascara:  0% ( 0/13)
# Test Accuracy of Booties: N/A (no training examples)
# Test Accuracy of Mask and Peel:  0% ( 0/12)
# Test Accuracy of Rompers: N/A (no training examples)
# Test Accuracy of Concealer:  0% ( 0/11)
# Test Accuracy of Water Bottle: 100% ( 1/ 1)
# Test Accuracy of Rucksacks: 37% ( 3/ 8)
# Test Accuracy of Shapewear:  0% ( 0/ 1)
# Test Accuracy of Tights:  0% ( 0/ 1)
# Test Accuracy of Footballs: 100% ( 2/ 2)
# Test Accuracy of Clothing Set: N/A (no training examples)
# Test Accuracy of Blazers: N/A (no training examples)
# Test Accuracy of Salwar and Dupatta: N/A (no training examples)
# Test Accuracy of Wristbands: 75% ( 3/ 4)
# Test Accuracy of Headband: 100% ( 3/ 3)
# Test Accuracy of Umbrellas:  0% ( 0/ 5)
# Test Accuracy of Body Lotion:  0% ( 0/ 6)
# Test Accuracy of Nail Essentials:  0% ( 0/ 6)
# Test Accuracy of Shrug:  0% ( 0/ 1)
# Test Accuracy of Eye Cream:  0% ( 0/ 6)
# Test Accuracy of Nehru Jackets: N/A (no training examples)
# Test Accuracy of Face Scrub and Exfoliator:  0% ( 0/ 5)
# Test Accuracy of Toner:  0% ( 0/ 5)
# Test Accuracy of Lehenga Choli: N/A (no training examples)
# Test Accuracy of Lip Plumper:  0% ( 0/ 4)
# Test Accuracy of Makeup Remover:  0% ( 0/ 3)
# Test Accuracy of Beauty Accessory:  0% ( 0/ 4)
# Test Accuracy of  Robe:  0% ( 0/ 3)
# Test Accuracy of Trolley Bag: N/A (no training examples)
# Test Accuracy of   Hat:  0% ( 0/ 3)
# Test Accuracy of Lounge Tshirts: N/A (no training examples)
# Test Accuracy of Tablet Sleeve: N/A (no training examples)
# Test Accuracy of Rain Trousers:  0% ( 0/ 1)
# Test Accuracy of Face Serum and Gel:  0% ( 0/ 2)
# Test Accuracy of Key chain:  0% ( 0/ 1)
# Test Accuracy of Ties and Cufflinks:  0% ( 0/ 2)
# Test Accuracy of Shoe Laces:  0% ( 0/ 1)
# Test Accuracy of Body Wash and Scrub:  0% ( 0/ 1)
# Test Accuracy of Mens Grooming Kit:  0% ( 0/ 1)
# Test Accuracy of Cushion Covers: N/A (no training examples)
# Test Accuracy of Hair Accessory: N/A (no training examples)
# Test Accuracy of  Ipad: N/A (no training examples)
#
# Printing 5 classes with greatest accuracy
# Test Accuracy of Sunglasses: 100%
# Test Accuracy of Earrings: 100%
# Test Accuracy of Accessory Gift Set: 100%
# Test Accuracy of Rain Jacket: 100%
# Test Accuracy of Water Bottle: 100%
#
# Test Accuracy (Overall): 70% (14640/20634)
